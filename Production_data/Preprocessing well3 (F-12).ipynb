# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
import plotly.offline as py
py.init_notebook_mode(connected = True)
import plotly.graph_objs as go
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data = pd.read_csv("F12.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  ON_STREAM_HRS  AVG_DP_TUBING  AVG_CHOKE_SIZE_P  DP_CHOKE_SIZE  \
# 0        1911          11.50     201.250000         14.484431      92.475107
# 1        1912          24.00     182.144942         22.832986      89.620148
# 2        1913          22.50     181.867887         31.249966      80.120465
# 3        1914          23.15     180.832060         28.518930      84.250990
# 4        1915          24.00     180.501045         30.227902      82.359026
#
#     AVG_WHP_P  AVG_WHT_P  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL
# 0  106.805939  16.294718        284.65      38888.67        385.01
# 1  120.888576  53.374330       1869.70     285246.16        107.13
# 2  113.718175  72.737631       3124.09     509954.88        101.16
# 3  116.830642  69.995943       2608.28     383426.67        100.97
# 4  115.434474  71.518347       3051.80     418474.00        104.89

# %%
df = data[['ON_STREAM_HRS',
          'AVG_DP_TUBING', 'AVG_CHOKE_SIZE_P', 'AVG_WHP_P', 'DP_CHOKE_SIZE', 'AVG_WHT_P',
          'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL']]

# %%
trace2 = go.Scatter(x = df['DATEPRD'],
                  y = (df['BORE_OIL_VOL']),
                  name = "Oil rate")
data = [trace2]
layout = {"title": "Oil rate"}
fig = go.Figure(data = data, layout = layout)
py.iplot(fig)
# Out:
# <div id="bda70227-5f85-4f8b-ac0f-d0d989f68a91" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("bda70227-5f85-4f8b-ac0f-d0d989f68a91")) {
# ...

# %%
df.describe()
# Out:
#        AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# count            3050.000000               3050.000000    3050.000000
# mean               80.729072                 33.292076      84.765924
# std               120.086902                 49.354533      72.511534
# min                 0.000000                  0.000000       0.000000
# 25%                 0.000000                  0.000000      32.454825
# 50%                 0.000000                  0.000000      38.721292
# 75%               239.422752                106.048231     171.190061
# max               317.701150                107.507552     314.409160
#
#        AVG_CHOKE_SIZE_P    AVG_WHP_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# count       3012.000000  3056.000000    3056.000000   3056.000000
# mean          69.254352    47.973013      19.292670   1498.563334
# std           30.179952    24.305518      22.750867   1662.851799
# min            0.000000     0.000000       0.000000      0.000000
# ...

# %%
df = df[(df["DATEPRD"] >= '2008-02-12') & (df['DATEPRD'] <= '2010-10-11')]

# %%
trace2 = go.Scatter(x = df['DATEPRD'],
                  y = (df['BORE_OIL_VOL']),
                  name = "Oil rate")
data = [trace2]
layout = {"title": "Oil rate"}
fig = go.Figure(data = data, layout = layout)
py.iplot(fig)
# Out:
# <div id="62674ac1-c233-4904-8484-61fd6e3c59a8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("62674ac1-c233-4904-8484-61fd6e3c59a8")) {
# ...

# %%
df.drop("BORE_WI_VOL", axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['DATEPRD', 'NPD_WELL_BORE_NAME', 'AVG_DOWNHOLE_PRESSURE',
#        'AVG_DOWNHOLE_TEMPERATURE', 'AVG_DP_TUBING', 'AVG_CHOKE_SIZE_P',
#        'AVG_WHP_P', 'DP_CHOKE_SIZE', 'BORE_OIL_VOL', 'BORE_GAS_VOL',
#        'BORE_WAT_VOL'],
#       dtype='object')

# %%
df.drop("NPD_WELL_BORE_NAME", axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 961 entries, 0 to 960
# Data columns (total 10 columns):
# DATEPRD                     961 non-null object
# AVG_DOWNHOLE_PRESSURE       955 non-null float64
# AVG_DOWNHOLE_TEMPERATURE    955 non-null float64
# AVG_DP_TUBING               955 non-null float64
# AVG_CHOKE_SIZE_P            932 non-null float64
# AVG_WHP_P                   961 non-null float64
# DP_CHOKE_SIZE               961 non-null float64
# BORE_OIL_VOL                961 non-null float64
# BORE_GAS_VOL                961 non-null float64
# BORE_WAT_VOL                961 non-null float64
# dtypes: float64(9), object(1)
# memory usage: 82.6+ KB

# %%
df.drop(df.loc[df['AVG_CHOKE_SIZE_P'] < 20].index, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 955 entries, 1 to 960
# Data columns (total 10 columns):
# DATEPRD                     955 non-null object
# AVG_DOWNHOLE_PRESSURE       949 non-null float64
# AVG_DOWNHOLE_TEMPERATURE    949 non-null float64
# AVG_DP_TUBING               949 non-null float64
# AVG_CHOKE_SIZE_P            926 non-null float64
# AVG_WHP_P                   955 non-null float64
# DP_CHOKE_SIZE               955 non-null float64
# BORE_OIL_VOL                955 non-null float64
# BORE_GAS_VOL                955 non-null float64
# BORE_WAT_VOL                955 non-null float64
# dtypes: float64(9), object(1)
# memory usage: 82.1+ KB

# %%
df.describe()
# Out:
#        AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# count             949.000000                949.000000     949.000000
# mean              257.612268                106.336058     187.635775
# std                19.369842                  3.418347      22.781108
# min               140.256360                 39.553670     109.578450
# 25%               245.760561                106.158232     172.481138
# 50%               257.744949                106.596790     179.884644
# 75%               271.372724                107.133754     197.605932
# max               317.701150                107.507552     314.409160
#
#        AVG_CHOKE_SIZE_P   AVG_WHP_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# count        926.000000  955.000000     955.000000    955.000000
# mean          54.799865   69.990607      38.204996   3608.591707
# std           14.639203   18.353540      17.653692   1406.771578
# min           21.333333    0.000000       0.768300      0.000000
# ...

# %%
df[(df['BORE_OIL_VOL'] < 2000) & (df['BORE_OIL_VOL'] > 1000)]
# Out:
#         DATEPRD  AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  \
# 1    2008-02-13             303.033518                105.402696
# 11   2008-02-23             292.088424                105.849013
# 47   2008-03-30             270.742382                105.902395
# 48   2008-03-31             271.557015                105.861701
# 60   2008-04-12             264.008220                105.837771
# 65   2008-04-17             262.977608                105.808794
# 75   2008-04-27             260.417398                105.816029
# 209  2008-09-10             273.545516                105.556727
# 396  2009-03-16             290.407780                105.890060
# 534  2009-08-02             251.032021                106.553193
# 566  2009-09-05             270.345357                106.247580
# 608  2009-10-17             253.228197                106.828707
# 614  2009-10-23             254.631824                106.788710
# ...

# %%
df.drop(df.loc[df['BORE_OIL_VOL'] < 1000].index, inplace = True)

# %%
df.describe()
# Out:
#        AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# count             897.000000                897.000000     897.000000
# mean              256.321336                106.493443     185.935054
# std                17.705031                  2.738328      17.841196
# min               219.365398                 39.553670     159.675662
# 25%               244.786415                106.212205     172.447863
# 50%               256.563422                106.609441     179.802981
# 75%               267.855628                107.205027     196.073310
# max               303.033518                107.507552     259.087354
#
#        AVG_CHOKE_SIZE_P   AVG_WHP_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# count        903.000000  903.000000     903.000000    903.000000
# mean          55.330744   70.398487      37.681850   3801.097032
# std           14.380427   16.148831      16.030189   1185.326317
# min           22.269454    0.000000      11.136473   1070.350000
# ...

# %%
df.drop(df.loc[df['AVG_WHP_P'] < 10].index, inplace = True)

# %%
df.describe()
# Out:
#        AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# count             895.000000                895.000000     895.000000
# mean              256.315852                106.494176     185.773432
# std                17.724437                  2.741345      17.529694
# min               219.365398                 39.553670     159.675662
# 25%               244.542651                106.217037     172.446587
# 50%               256.529002                106.610671     179.770173
# 75%               267.889414                107.205056     196.036341
# max               303.033518                107.507552     230.857105
#
#        AVG_CHOKE_SIZE_P   AVG_WHP_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# count        901.000000  901.000000     901.000000    901.000000
# mean          55.357401   70.553611      37.692360   3798.361665
# std           14.385236   15.826777      16.046416   1185.215677
# min           22.269454   44.401403      11.136473   1070.350000
# ...

# %%
df.dropna(inplace = True)

# %%
df.drop(df.loc[df['BORE_OIL_VOL'] > 5700].index, inplace = True)

# %%
trace2 = go.Scatter(x = df['DATEPRD'],
                  y = (df['BORE_OIL_VOL']),
                  name = "Oil rate")
data = [trace2]
layout = {"title": "Oil rate"}
fig = go.Figure(data = data, layout = layout)
py.iplot(fig)
# Out:
# <div id="b824971f-194a-41c8-b92c-7a198743ff00" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("b824971f-194a-41c8-b92c-7a198743ff00")) {
# ...

# %%
df.drop("DATEPRD", axis = 1, inplace = True)

# %%
df.head()
# Out:
#    AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 1             303.033518                105.402696     182.144942
# 2             295.586061                105.775486     181.867887
# 3             297.662702                105.751875     180.832060
# 4             295.935519                105.811114     180.501045
# 5             295.551657                105.831299     180.345781
#
#    AVG_CHOKE_SIZE_P   AVG_WHP_P  DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  \
# 1         22.832986  120.888576      89.620148       1869.70     285246.16
# 2         31.249966  113.718175      80.120465       3124.09     509954.88
# 3         28.518930  116.830642      84.250990       2608.28     383426.67
# 4         30.227902  115.434474      82.359026       3051.80     418474.00
# 5         29.974052  115.205876      82.168501       2982.63     422763.00
#
#    BORE_WAT_VOL
# 1          7.13
# 2          1.16
# 3          0.97
# 4          4.89
# 5          1.85

# %%
df.to_csv("forecast.csv")

# %%
X = df.iloc[:,0:6]
Y = df.iloc[:,6]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.preprocessing import MinMaxScaler, Normalizer, MaxAbsScaler, StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# %%
scaler_x = MinMaxScaler()
x_train = scaler_x.fit_transform(X.as_matrix())

# %%
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(Y.reshape(-1,1))
